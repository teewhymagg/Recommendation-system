# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import KFold

# %%
df = pd.read_csv('diabetes.csv')
df_original = df.copy()
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Overview

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %% [markdown]
#  # Missing Value analysis

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0, np.NaN)

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# The missing values will be filled with the median values of each variable.

def median_target(var):   
    
    temp = df[df[var].notnull()]
    
    temp = temp[[var, 'Outcome']].groupby(['Outcome'])[[var]].median().reset_index()
    
    return temp

# %%
# The values to be given for incomplete observations are given the median value of people who are not sick and the median values of people who are sick.

columns = df.columns

columns = columns.drop("Outcome")

for col in columns:
    
    df.loc[(df['Outcome'] == 0 ) & (df[col].isnull()), col] = median_target(col)[col][0]
    df.loc[(df['Outcome'] == 1 ) & (df[col].isnull()), col] = median_target(col)[col][1]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
# 2            8    183.0           64.0           32.0    169.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Outlier analysis

# %%
Q1 = df["BloodPressure"].quantile(0.25)
Q3 = df["BloodPressure"].quantile(0.75)
IQR = Q3-Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

# %%
upper
# Out:
# 104.0

# %%
lower
# Out:
# 40.0

# %%
for feature in df:
    print(feature)
# Out:
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age
# Outcome

# %%
# Checking if there are outliers
for feature in df:
    
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    
    if df[(df[feature] > upper)].any(axis=None):
        print(feature,"yes")
    else:
        print(feature, "no")
# Out:
# Pregnancies yes
# Glucose no
# BloodPressure yes
# SkinThickness yes
# Insulin yes
# BMI yes
# DiabetesPedigreeFunction yes
# Age yes
# Outcome no

# %%
# Checking if there are extreme outliers
for feature in df:
    
    Q1 = df[feature].quantile(0.05)
    Q3 = df[feature].quantile(0.95)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    
    if df[(df[feature] > upper)].any(axis=None):
        print(feature,"yes")
    else:
        print(feature, "no")
# Out:
# Pregnancies no
# Glucose no
# BloodPressure no
# SkinThickness yes
# Insulin yes
# BMI no
# DiabetesPedigreeFunction no
# Age no
# Outcome no

# %%
# Checking if there are outliers
for feature in df:
    
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    
    if df[(df[feature] < lower)].any(axis=None):
        print(feature,"yes")
    else:
        print(feature, "no")
# Out:
# Pregnancies no
# Glucose no
# BloodPressure yes
# SkinThickness yes
# Insulin no
# BMI no
# DiabetesPedigreeFunction no
# Age no
# Outcome no

# %%
# Checking if there are extreme outliers
for feature in df:
    
    Q1 = df[feature].quantile(0.05)
    Q3 = df[feature].quantile(0.95)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    
    if df[(df[feature] < lower)].any(axis=None):
        print(feature,"yes")
    else:
        print(feature, "no")
# Out:
# Pregnancies no
# Glucose no
# BloodPressure no
# SkinThickness no
# Insulin no
# BMI no
# DiabetesPedigreeFunction no
# Age no
# Outcome no

# %%
# The extreme outliers will be replaced with median values

# %%
# Calculate the median values for 'SkinThickness' and 'Insulin'
median_skinthickness = df['SkinThickness'].median()
median_insulin = df['Insulin'].median()

# Define the upper threshold for extreme outliers
Q1_skin = df['SkinThickness'].quantile(0.05)
Q3_skin = df['SkinThickness'].quantile(0.95)
IQR_skin = Q3_skin - Q1_skin
upper_skin = Q3_skin + 1.5 * IQR_skin

Q1_insulin = df['Insulin'].quantile(0.05)
Q3_insulin = df['Insulin'].quantile(0.95)
IQR_insulin = Q3_insulin - Q1_insulin
upper_insulin = Q3_insulin + 1.5 * IQR_insulin

# Replace extreme outliers with the median values
df.loc[df['SkinThickness'] > upper_skin, 'SkinThickness'] = median_skinthickness
df.loc[df['Insulin'] > upper_insulin, 'Insulin'] = median_insulin

# %%
plt.figure(figsize=(10, 6))

# Plot histogram for original Insulin data
plt.hist(df_original['Insulin'].dropna(), bins=30, alpha=0.5, label='Original Insulin')

# Plot histogram for Insulin data after replacing outliers
plt.hist(df['Insulin'].dropna(), bins=30, alpha=0.5, label='Insulin After Outlier Replacement')

plt.title('Comparison of Insulin Levels Before and After Outlier Replacement')
plt.xlabel('Insulin Level')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plot histogram for original SkinThickness data
plt.hist(df_original['SkinThickness'].dropna(), bins=30, alpha=0.5, label='Original SkinThickness')

# Plot histogram for SkinThickness data after replacing outliers
plt.hist(df['SkinThickness'].dropna(), bins=30, alpha=0.5, label='SkinThickness After Outlier Replacement')

plt.title('Comparison of SkinThickness Before and After Outlier Replacement')
plt.xlabel('SkinThickness')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
# It is visible that the original dataframe consists of many 0's and also has values greater than 600, 
# while the modified dataset doesn't have 0s and no values greater than approximately 600

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
# 2            8    183.0           64.0           32.0    169.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.to_csv('diabetes_modified.csv', index=False)

# %%
y = df["Outcome"]
X = df.drop(["Outcome"], axis = 1)

cols = X.columns
index = X.index

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
# 2            8    183.0           64.0           32.0    169.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.preprocessing import RobustScaler
transformer = RobustScaler().fit(X)
X = transformer.transform(X)
X = pd.DataFrame(X, columns = cols, index = index)

# %%
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0          0.6  0.765432          0.000       1.000000  1.000000  0.170330
# 1         -0.4 -0.790123         -0.375       0.142857  0.000000 -0.598901
# 2          1.0  1.629630         -0.500       0.571429  1.000000 -0.961538
# 3         -0.4 -0.691358         -0.375      -0.714286 -0.126866 -0.434066
# 4         -0.6  0.493827         -2.000       1.000000  0.977612  1.214286
#
#    DiabetesPedigreeFunction       Age
# 0                  0.665359  1.235294
# 1                 -0.056209  0.117647
# 2                  0.783007  0.176471
# 3                 -0.537255 -0.470588
# 4                  5.007843  0.235294

# %% [markdown]
# # Model

# %%
models = []
models.append(('LR', LogisticRegression(random_state = 12345)))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier(random_state = 12345)))
models.append(('RF', RandomForestClassifier(random_state = 12345)))
models.append(('SVM', SVC(gamma='auto', random_state = 12345)))
models.append(('XGB', GradientBoostingClassifier(random_state = 12345)))

# evaluate each model in turn
results = []
names = []

for name, model in models:
    
        kfold = KFold(n_splits = 10)
        
        cv_results = cross_val_score(model, X, y, cv = 10, scoring= "accuracy")
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
        print(msg)
        
# boxplot algorithm comparison
fig = plt.figure(figsize=(15,10))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.772163 (0.033374)
# KNN: 0.855485 (0.024198)
# CART: 0.839884 (0.025269)
# RF: 0.880246 (0.033644)
# SVM: 0.854118 (0.030351)
# XGB: 0.892003 (0.029439)

# %% [markdown]
# # Tuning models using GridSearchCV

# %%
# Random Forest
rf_params = {"n_estimators" :[100,200,500,1000], 
             "max_features": [3,5,7], 
             "min_samples_split": [2,5,10,30],
            "max_depth": [3,5,8,None]}

rf_model = RandomForestClassifier(random_state = 12345)

gs_cv = GridSearchCV(rf_model, 
                    rf_params,
                    cv = 10,
                    n_jobs = -1,
                    verbose = 2).fit(X, y)
# Out:
# Fitting 10 folds for each of 192 candidates, totalling 1920 fits
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s

# %%
gs_cv.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 7,
#  'min_samples_split': 10,
#  'n_estimators': 100}

# %%
rf_tuned = RandomForestClassifier(**gs_cv.best_params_)

# %%
rf_tuned = rf_tuned.fit(X,y)

# %%
cross_val_score(rf_tuned, X, y, cv = 10).mean()
# Out:
# 0.8867737525632263

# %%
xgb = GradientBoostingClassifier(random_state = 12345)

# %%
xgb_params = {
    "learning_rate": [0.01, 0.1, 0.2, 1],
    "min_samples_split": np.linspace(0.1, 0.5, 10),
    "max_depth":[3,5,8],
    "subsample":[0.5, 0.9, 1.0],
    "n_estimators": [100,1000]}

# %%
xgb_cv_model  = GridSearchCV(xgb,xgb_params, cv = 10, n_jobs = -1, verbose = 2).fit(X, y)
# Out:
# Fitting 10 folds for each of 720 candidates, totalling 7200 fits
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.3s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=3, min_samples_split=2, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.4s
# [CV] END max_depth=3, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=2, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=5, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=5, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=3, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=3, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=3, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=3, min_samples_split=30, n_estimators=1000; total time=   0.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=5, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=30, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=8, max_features=3, min_samples_split=5, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=500; total time=   0.5s
# [CV] END max_depth=8, max_features=3, min_samples_split=30, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=5, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=10, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=30, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# ...
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.32222222222222224, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.32222222222222224, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=0.9; total time=   1.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.3666666666666667, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=0.9; total time=   1.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=0.9; total time=   0.8s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=0.9; total time=   1.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=1000, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=1000, subsample=0.9; total time=   0.8s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=1000, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=1, max_depth=3, min_samples_split=0.5, n_estimators=1000, subsample=1.0; total time=   0.8s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.1, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.1, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.1, n_estimators=1000, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.1, n_estimators=1000, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.1, n_estimators=1000, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.1, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=1000, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=1000, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=1000, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.18888888888888888, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=1000, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=1000, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.23333333333333334, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=1000, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=1000, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=1000, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.2777777777777778, n_estimators=1000, subsample=1.0; total time=   0.9s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.32222222222222224, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.32222222222222224, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.32222222222222224, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.32222222222222224, n_estimators=1000, subsample=0.9; total time=   1.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=0.9; total time=   0.7s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=0.9; total time=   0.7s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.3666666666666667, n_estimators=1000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4111111111111111, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4111111111111111, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4111111111111111, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=0.9; total time=   0.7s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=0.9; total time=   0.8s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.4555555555555556, n_estimators=1000, subsample=1.0; total time=   1.0s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.5, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.5, n_estimators=1000, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.5, n_estimators=1000, subsample=0.9; total time=   1.0s
# [CV] END learning_rate=1, max_depth=5, min_samples_split=0.5, n_estimators=1000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=1000, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=1000, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=1000, subsample=0.9; total time=   1.0s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.1, n_estimators=1000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.14444444444444446, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.14444444444444446, n_estimators=100, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.14444444444444446, n_estimators=1000, subsample=0.9; total time=   1.0s
# [CV] END learning_rate=1, max_depth=8, min_samples_split=0.18888888888888888, n_estimators=100, subsample=0.5; total time=   0.1s

# %%
xgb_cv_model.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 8,
#  'min_samples_split': 0.32222222222222224,
#  'n_estimators': 1000,
#  'subsample': 0.9}

# %%
xgb_tuned = GradientBoostingClassifier(**xgb_cv_model.best_params_).fit(X,y)

# %%
cross_val_score(xgb_tuned, X, y, cv = 10).mean()
# Out:
# 0.8854921394395079

# %% [markdown]
# # Comparison

# %%
models = []

models.append(('RF', RandomForestClassifier(random_state = 12345, max_depth = 5, max_features = 7, min_samples_split = 10, n_estimators = 100)))
models.append(('XGB', GradientBoostingClassifier(random_state = 12345, learning_rate = 0.01, max_depth = 8, min_samples_split = 0.322222, n_estimators = 1000, subsample = 0.9)))

results = []
names = []

# %%
for name, model in models:
    
        kfold = KFold(n_splits = 10)
        cv_results = cross_val_score(model, X, y, cv = 10, scoring= "accuracy")
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
        print(msg)
        
# boxplot algorithm comparison
fig = plt.figure(figsize=(15,10))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# RF: 0.894566 (0.028071)
# XGB: 0.895899 (0.017120)

# %%
# Columns for which you want to find the max and min values
columns = ['DiabetesPedigreeFunction', 'BMI', 'SkinThickness', 'Insulin', 'Glucose', 'BloodPressure', 'Age', 'Pregnancies']

# Initialize dictionaries to store the max and min values
max_values = {}
min_values = {}

# Iterate over the columns and compute max and min for each
for col in columns:
    max_values[col] = df[col].max()
    min_values[col] = df[col].min()

# Display the results
print("Maximum Values:")
for col, max_val in max_values.items():
    print(f"{col}: {max_val}")

print("\nMinimum Values:")
for col, min_val in min_values.items():
    print(f"{col}: {min_val}")
# Out:
# Maximum Values:
# DiabetesPedigreeFunction: 2.42
# BMI: 67.1
# SkinThickness: 63.0
# Insulin: 600.0
# Glucose: 199.0
# BloodPressure: 122.0
# Age: 81
# Pregnancies: 17
#
# Minimum Values:
# DiabetesPedigreeFunction: 0.078
# BMI: 18.2
# SkinThickness: 7.0
# Insulin: 14.0
# Glucose: 44.0
# BloodPressure: 24.0
# Age: 21
# Pregnancies: 0
